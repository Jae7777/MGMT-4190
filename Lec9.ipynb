# %% [markdown]
# ### Data preprocessing

# %%
#1. Lets read the file to a dataframe and print all the rows and columns
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lmanikon/lmanikon.github.io/master/teaching/datasets/airlineSatisfaction.csv')
df.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
#FInding the unique  values of satisfaction column
print(df['satisfaction'].unique())
# Out:
# ['neutral or dissatisfied' 'satisfied']

# %%
#2. Find the total number of data points in this dataset?
print(df.shape[0])
# Out:
# 103904

# %%
#3. Total number of attributes in this dataset
print(df.shape[1])
# Out:
# 24

# %%
#4. Check if there are any missing values in this dataset -- if yes, print true or else print false
print(df.isnull().any().any())
# Out:
# True

# %%
#5. If there are missing values, print the total number of missing values
print(df.isnull().sum().sum())
# Out:
# 310

# %%
#6. Now drop all the rows with atleast one missing value
df = df.dropna(how="any")
print(df.shape)
print(df.isnull().any().sum())
# Out:
# (103594, 24)
# 0

# %%
#7. Lets print the summary statistics
print(df.describe())
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  103594.000000  103594.000000    103594.000000          103594.000000
# mean    64942.428625      39.380466      1189.325202               2.729753
# std     37460.816597      15.113125       997.297235               1.327866
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32562.250000      27.000000       414.000000               2.000000
# 50%     64890.000000      40.000000       842.000000               3.000000
# 75%     97370.500000      51.000000      1743.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103594.000000           103594.000000
# mean                            3.060081                2.756984
# std                             1.525233                1.398934
# ...

# %%
#8. Lets say drop the column 'id'
df = df.drop(columns=['id'])
print(df)
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %%
#9. Categorical attributes to numerical attributes

#Gender
#Male -- 1; Female -- 0



#Can you write a Lambda function?
df['Gender'] = df['Gender'].apply(lambda x: 1 if x == 'Male' else 0)
print(df)
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0            1     Loyal Customer   13  Personal Travel  Eco Plus
# 1            1  disloyal Customer   25  Business travel  Business
# 2            0     Loyal Customer   26  Business travel  Business
# 3            0     Loyal Customer   25  Business travel  Business
# 4            1     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899       0  disloyal Customer   23  Business travel       Eco
# 103900       1     Loyal Customer   49  Business travel  Business
# 103901       1  disloyal Customer   30  Business travel  Business
# 103902       0  disloyal Customer   22  Business travel       Eco
# 103903       1     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %%
#10. Take the 'satisfaction' column and perform this conversion -- "neutral or dissatisfied": -1; "satisfied":1

df['satisfaction'] = df['satisfaction'].apply(lambda x: -1 if x == 'neutral or dissatisfied' else 1)
print(df)
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0            1     Loyal Customer   13  Personal Travel  Eco Plus
# 1            1  disloyal Customer   25  Business travel  Business
# 2            0     Loyal Customer   26  Business travel  Business
# 3            0     Loyal Customer   25  Business travel  Business
# 4            1     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899       0  disloyal Customer   23  Business travel       Eco
# 103900       1     Loyal Customer   49  Business travel  Business
# 103901       1  disloyal Customer   30  Business travel  Business
# 103902       0  disloyal Customer   22  Business travel       Eco
# 103903       1     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %%
#11. Flight distance -- Binarization

#FD >=1000 -- 1
#Otherwise, -- 0
df['Flight Distance'] = df['Flight Distance'].apply(lambda x: 1 if x >= 1000 else 0)
print(df)
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0            1     Loyal Customer   13  Personal Travel  Eco Plus
# 1            1  disloyal Customer   25  Business travel  Business
# 2            0     Loyal Customer   26  Business travel  Business
# 3            0     Loyal Customer   25  Business travel  Business
# 4            1     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899       0  disloyal Customer   23  Business travel       Eco
# 103900       1     Loyal Customer   49  Business travel  Business
# 103901       1  disloyal Customer   30  Business travel  Business
# 103902       0  disloyal Customer   22  Business travel       Eco
# 103903       1     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                     0                      3
# 1                     0                      3
# ...

# %%
#12. Age attribute -- Discretize
#[7,27) -- 1
#[27,51) -- 2
#[51,85) -- 3
df['Age'] = df['Age'].apply(
  lambda x: 1 if x >= 7 and x < 27 else 2 if x >= 27 and x < 51 else 3 if x >= 51 and x < 85 else x
)

print(df)
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0            1     Loyal Customer    1  Personal Travel  Eco Plus
# 1            1  disloyal Customer    1  Business travel  Business
# 2            0     Loyal Customer    1  Business travel  Business
# 3            0     Loyal Customer    1  Business travel  Business
# 4            1     Loyal Customer    3  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899       0  disloyal Customer    1  Business travel       Eco
# 103900       1     Loyal Customer    2  Business travel  Business
# 103901       1  disloyal Customer    2  Business travel  Business
# 103902       0  disloyal Customer    1  Business travel       Eco
# 103903       1     Loyal Customer    2  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                     0                      3
# 1                     0                      3
# ...

# %%
#13. perform random sampling
#Sample 100 random datapoints from our dataframe df -- sample without replacement
print(df.sample(n=100, replace=False))
# Out:
#        Gender   Customer Type  Age   Type of Travel     Class  \
# 13736       1  Loyal Customer    1  Personal Travel       Eco
# 22646       1  Loyal Customer    1  Business travel  Business
# 47144       0  Loyal Customer    2  Business travel  Business
# 42225       0  Loyal Customer    3  Business travel  Business
# 14971       1  Loyal Customer    2  Business travel  Business
# ...       ...             ...  ...              ...       ...
# 39965       1  Loyal Customer    2  Business travel  Eco Plus
# 71306       1  Loyal Customer    2  Business travel  Business
# 52447       0  Loyal Customer    2  Personal Travel       Eco
# 96501       0  Loyal Customer    1  Personal Travel  Eco Plus
# 75646       0  Loyal Customer    2  Business travel       Eco
#
#        Flight Distance  Inflight wifi service  \
# 13736                0                      2
# 22646                1                      2
# 47144                1                      2
# ...

# %%
#14. Split the dataframe df into X and y -- X-- corresponds to feature set; y -- class label

#X - excluding 'satisfaction'
#y - 'satisfaction'
#y = f(X) -- y-class label variable; X -- feature set
X = df.drop(columns=['satisfaction'])
y = df['satisfaction']
print(X)  
print(y)
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0            1     Loyal Customer    1  Personal Travel  Eco Plus
# 1            1  disloyal Customer    1  Business travel  Business
# 2            0     Loyal Customer    1  Business travel  Business
# 3            0     Loyal Customer    1  Business travel  Business
# 4            1     Loyal Customer    3  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899       0  disloyal Customer    1  Business travel       Eco
# 103900       1     Loyal Customer    2  Business travel  Business
# 103901       1  disloyal Customer    2  Business travel  Business
# 103902       0  disloyal Customer    1  Business travel       Eco
# 103903       1     Loyal Customer    2  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                     0                      3
# 1                     0                      3
# ...

# %%
#15. Aggregate -- based on the type of travel -- summing up all the values
print(df.groupby('Type of Travel').sum())
# Out:
#                  Gender                                      Customer Type  \
# Type of Travel
# Business travel   35032  disloyal CustomerLoyal CustomerLoyal CustomerL...
# Personal Travel   15986  Loyal CustomerLoyal CustomerLoyal CustomerLoya...
#
#                     Age                                              Class  \
# Type of Travel
# Business travel  146443  BusinessBusinessBusinessBusinessBusinessBusine...
# Personal Travel   63979  Eco PlusEcoEcoEco PlusEcoEcoEcoEcoEcoEcoEcoEco...
#
#                  Flight Distance  Inflight wifi service  \
# Type of Travel
# Business travel            35240                 201755
# Personal Travel             8463                  81031
#
#                  Departure/Arrival time convenient  Ease of Online booking  \
# Type of Travel
# Business travel                             199699                  205970
# Personal Travel                             117307                   79637
#
# ...
